# %%
import json
import glob
import os

def merge_json_files(input_path, output_file):
    """
    Merge content from multiple JSON files into a single JSON file.
    
    Args:
        input_path (str): Path to directory containing JSON files
        output_file (str): Path for the output merged JSON file
    """
    merged_data = []
    
    # Get all JSON files in the directory
    json_files = glob.glob(os.path.join(input_path, "*.json"))
    
    for file_path in json_files:
        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                data = json.load(file)
                
                # Extract relevant information
                doc_info = {
                    'title': data.get('title'),
                    'id_doc': data.get('id_doc'),
                    'location': data.get('location'),
                    'doc_type': data.get('doc_type'),
                    'date': data.get('date'),
                    'department': data.get('department'),
                    'doc_type_en': data.get('doc_type_en'),
                    'content': data.get('data', {}).get('content')
                }
                
                merged_data.append(doc_info['content'])
                print(f"Processed: {file_path}")
                
        except json.JSONDecodeError as e:
            print(f"Error reading {file_path}: {str(e)}")
        except Exception as e:
            print(f"Unexpected error processing {file_path}: {str(e)}")
    
    # Write merged data to output file
    try:
        with open(output_file, 'w', encoding='utf-8') as outfile:
            json.dump(merged_data, outfile, ensure_ascii=False, indent=2)
        print(f"\nSuccessfully merged {len(merged_data)} files into {output_file}")
    except Exception as e:
        print(f"Error writing output file: {str(e)}")

# Example usage
if __name__ == "__main__":
    input_directory = "/home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong"  # Directory containing your JSON files
    output_file = "merged_contents.json"  # Name of the output file
    
    merge_json_files(input_directory, output_file)
# Out:
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_2.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_7.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_37.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_16.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_42.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_25.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_44.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_10.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_30.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_36.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_19.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_48.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Luật_sửa_đổi,_bổ_sung_một copy.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_40.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_27.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_29.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_46.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_43.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_24.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_8.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_13.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_17.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_33.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Luật_Đường_bộ_2024.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_12.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_28.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Luật_sửa_đổi,_bổ_sung_một.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_23.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_15.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_1.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Luật_sửa_đổi,_bổ_sung_Luật_Giao_thông_đường_thủy_nội_địa_2014.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_22.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_34.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_5.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_0.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_39.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_32.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Luật_Đường_sắt_2017.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_35.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_49.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_14.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_41.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_47.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_6.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_9.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_26.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Luật_Hàng_không_dân_dụng_Việt_Nam_năm_2006.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_3.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_45.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_31.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Luật_Giao_thông_đường_bộ.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_21.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_18.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_20.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_11.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_4.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Nghi_dinh_giao_thong_38.json
# Processed: /home/drissdo/Desktop/VN_LAW_QA_SYSTEM/data/raw/Giao Thong/Luật_Trật_tự,_an_toàn_giao_thông_đường_bộ.json
#
# Successfully merged 58 files into merged_contents.json
