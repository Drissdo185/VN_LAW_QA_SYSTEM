# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://tuyensinh.hcmiu.edu.vn/'

reponse = requests.get(url)
reponse.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(reponse.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="vi-VN" prefix="og: https://ogp.me/ns#">
# ...
