# %%
import pandas as pd

# %%
df = pd.read_csv('benchmark.csv')

# %%
df
# Out:
#                                               cau_hoi  \
# 0   Mức phạt cho hành vi sử dụng còi trong khu dân...
# 1   Nếu tài xế không thắt dây an toàn khi lái xe, ...
# 2   Mức phạt cho hành vi điều khiển xe chạy quá tố...
# 3   Mức phạt khi điều khiển xe mà trong hơi thở có...
# 4        Lái xe không có giấy phép lái xe sẽ bị phạt:
# 5   Điều khiển xe lạng lách đánh võng và chạy quá ...
# 6   Tài xế vừa sử dụng điện thoại khi lái xe vừa k...
# 7   Trường hợp lái xe có nồng độ cồn 0,1 miligam/1...
# 8   Tài xế 17 tuổi lái xe mà không có giấy phép lá...
# 9   Người lái xe chạy quá tốc độ 30 km/h và dừng x...
# 10  Anh A lái xe trên đường cao tốc, thấy trời mưa...
# 11  Chị B lái xe đưa con nhỏ 8 tuổi đi học, để con...
# 12  Anh C lái xe về nhà lúc 23:30, gặp đèn đỏ nhưn...
# 13  Anh D dừng xe trước cổng trường học để đón con...
# 14  Chị E lái xe trên đường, thấy một người bạn đi...
# 15  Tài xế dừng xe tại một vị trí không rõ biển bá...
# ...
