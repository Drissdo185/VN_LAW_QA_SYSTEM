# %%
import pandas as pd

# %%
df = pd.read_csv("/home/drissdo/Desktop/VN_LAW_QA_SYSTEM/TEST/benchmark_2.csv")

# %%
df
# Out:
#                                              question  \
# 0   Mức phạt tiền cho việc không thắt dây an toàn ...
# 1   Vi phạm nào sau đây bị phạt từ 400.000 đến 600...
# 2   Mức phạt cho việc sử dụng điện thoại khi điều ...
# 3   Hành vi không chấp hành hiệu lệnh đèn tín hiệu...
# 4   Mức phạt cho việc chở quá số người trên ô tô c...
# ..                                                ...
# 57  Mức phạt cho việc chở người trên xe được kéo l...
# 58  Hành vi lái xe không có giấy phép lái xe bị ph...
# 59        Vi phạm nào bị trừ 4 điểm giấy phép lái xe?
# 60  Mức phạt cho việc chở hàng không chằng buộc là...
# 61  Hành vi điều khiển xe không có thiết bị giảm t...
#
#                        option_a                      option_b  \
# 0        350.000 - 400.000 đồng        300.000 - 400.000 đồng
# 1                  Không có còi         Chạy quá tốc độ 5km/h
# 2        350.000 - 400.000 đồng    4.000.000 - 6.000.000 đồng
# 3                        2 điểm                        4 điểm
# ...
